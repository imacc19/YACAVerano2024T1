# %% [markdown]
# # EJERCICIO 12

# %%
# EJERCICIO NUMERO 12
import codigo_base.jose as j
import codigo_base.gustavo as g
import codigo_base.milagros as m
import codigo_base.rosario as r
import codigo_base.isai as i
import codigo_base.formatear_tabla as ft


import codigo_base.lopez as p
import codigo_base.ortiz as o
import codigo_base.falcon as f


# Graficas
import codigo_base.reyes as re
import codigo_base.montaño as me
import codigo_base.caracas as ca
import codigo_base.paz as pa
import codigo_base.atanacio as at


import codigo_base.chavez as c
import codigo_base.fr as fr
import codigo_base.fa as fa
import codigo_base.chema as che
import codigo_base.escamilla as esc

# %%
datos = [250, 790, 470, 510, 500, 330,
         300, 750, 580, 740, 420, 260,
         440, 770, 400, 540, 530, 330,
         390, 380, 340, 460, 530, 260,
         410, 360, 270, 510, 630, 330]

lim_inf, lim_sup, mrks = c.clases_grouped(datos)
freq_absoluta, clases = che.fa_grouped(datos, lim_inf, lim_sup)
freq_relativa = fr.obtener_fr(freq_absoluta)
frecuencia_acumulada = fa.obtener_fa(freq_relativa)
tbl = esc.tabla_grouped(lim_inf, lim_sup, mrks, freq_absoluta, freq_relativa, frecuencia_acumulada)
print(tbl)


labelx = "Nutricion"
labely = "Calorias"
titulo = "comida Sandwitch"

histograma = ca.plot_hist(clases, freq_relativa, mrks, labelx, labely, titulo)
ojiva = at.plot_ojiva(clases, frecuencia_acumulada, mrks, labelx, labely, titulo)
# Out:
#    Limite inferior  Limite superior  Marcas de clase  Frecuencia absoluta  \
# 0            250.0            340.0            295.0                    9
# 1            340.0            430.0            385.0                    6
# 2            430.0            520.0            475.0                    6
# 3            520.0            610.0            565.0                    4
# 4            610.0            700.0            655.0                    1
# 5            700.0            790.0            745.0                    4
#
#    Frecuencia Relativa  Frecuencia Acumulada
# 0            30.000000             30.000000
# 1            20.000000             50.000000
# 2            20.000000             70.000000
# 3            13.333333             83.333333
# 4             3.333333             86.666667
# 5            13.333333            100.000000

# %% [markdown]
# # EJERCICIO 15

# %%
datos15 = [ "Ramírez", "García", "González", "Rodríguez", "Pérez", "Martínez", "García", "López", "Gutiérrez", "López",
            "Rodríguez", "Martínez", "Rodríguez", "Hernández", "García", "García", "González", "Hernández", "García", 
            "Gutiérrez", "Hernández", "López", "Pérez", "González", "Martínez", "Ramírez", "García", "Rodríguez", "Hernández", 
            "Sánchez", "Hernández", "González", "Rodríguez", "Sánchez", "Hernández", "González", "Gutiérrez", "Martínez", 
            "González", "Rodríguez", "Rodríguez", "Martínez", "Ramírez", "Pérez", "Sánchez", "Hernández", "Hernández", 
            "González", "García", "Hernández", "Rodríguez", "López", "Sánchez", "Rodríguez", "Ramírez", "López", "Martínez", 
            "García", "García", "Hernández", "González", "López", "Martínez", "López", "García", "Sánchez", "García", 
            "Hernández", "Flores", "Pérez", "González", "González", "López", "Martínez", "González", "Martínez", "Hernández",
            "Ramírez", "López", "Sánchez", "Ramírez", "Gutiérrez", "Sánchez", "Flores", "García", "Martínez", "García", 
            "Flores", "Pérez", "López", "Hernández", "Martínez", "García", "Hernández", "Flores", "Pérez", "González", 
            "Hernández", "Sánchez", "Martínez"]


clases, fa_absoluta = r.frec_abs(datos15)
clases_sorted = o.clases_str_sort(clases)
        
fa_sorted = m.sort_clases_fa(clases, clases_sorted, fa_absoluta)
fr_relativa =  g.frecuencia_rel(fa_sorted)
fr_acum = j.calcular_frecuencia_a(fr_relativa)
        
tabla = ft.imptabla(clases_sorted, fa_sorted, fr_relativa, fr_acum)
print (tabla)
        
marcas_texto = clases_sorted

titulo = "Apellidos"

pastel = re.plot_pie(fr_relativa,marcas_texto,titulo)
# Out:
#        Clases  F absoluta  F relativa  F acumulada
# 0      Flores           4         4.0          4.0
# 1      García          14        14.0         18.0
# 2    González          12        12.0         30.0
# 3   Gutiérrez           4         4.0         34.0
# 4   Hernández          15        15.0         49.0
# 5       López          10        10.0         59.0
# 6    Martínez          12        12.0         71.0
# 7       Pérez           6         6.0         77.0
# 8     Ramírez           6         6.0         83.0
# 9   Rodríguez           9         9.0         92.0
# 10    Sánchez           8         8.0        100.0
